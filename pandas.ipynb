# %% [markdown]
# <a href="https://colab.research.google.com/github/fkhaaan/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ferrrari", "Ford", "BMW"],
  'counts': [3, 7, 2, 8, 1, 9, 3]
}


df = pd.DataFrame(mydataset)
print(df)
# Out:
#        cars  counts
# 0       BMW       3
# 1     Volvo       7
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1
# 5      Ford       9
# 6       BMW       3

# %%
df.head() # deafult 5 rows
# Out:
#        cars  counts
# 0       BMW       3
# 1     Volvo       7
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1

# %%
df.tail()
# Out:
#        cars  counts
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1
# 5      Ford       9
# 6       BMW       3

# %%
df.shape
# Out:
# (7, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
df.describe() # numeric columns only
# Out:
#          counts
# count  7.000000
# mean   4.714286
# std    3.199702
# min    1.000000
# 25%    2.500000
# 50%    3.000000
# 75%    7.500000
# max    9.000000

# %%
df.iloc[2:]
# Out:
#        cars  counts
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1
# 5      Ford       9
# 6       BMW       3

# %%
df.loc[2:5, "cars"]
# Out:
# 2        Ford
# 3       Tesla
# 4    Ferrrari
# 5        Ford
# Name: cars, dtype: object

# %%
print(df)
# Out:
#        cars  counts
# 0       BMW       3
# 1     Volvo       7
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1
# 5      Ford       9
# 6       BMW       3

# %%
df[df["counts"] != 3]
# Out:
#        cars  counts
# 1     Volvo       7
# 2      Ford       2
# 3     Tesla       8
# 4  Ferrrari       1
# 5      Ford       9

# %%
# df.mean(numeric_only=True)
df['counts'].mean()
# Out:
# np.float64(4.714285714285714)

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaFerrrariFordBMW
# counts                                  33
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      1
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        9
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    3.0
# dtype: float64

# %%
df.count()
# Out:
# cars      7
# counts    7
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    3.199702
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", None, "Ford"],
    "counts": [3, 4, 6, None, 3, None]
}

df_missing = pd.DataFrame(data_with_missing)

print(df_missing)
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     4.0
# 2   None     6.0
# 3  Tesla     NaN
# 4   None     3.0
# 5   Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(subset=['cars'])
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     4.0
# 3  Tesla     NaN
# 5   Ford     NaN

# %%
df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     4.0
# 2  unknown     6.0
# 3    Tesla     0.0
# 4  unknown     3.0
# 5     Ford     0.0

# %%
# df = pd.read_csv("Titanic-Dataset.csv")
df = pd.read_excel("test.xlsx")

df.tail()


# df = pd.read_excel("Titanic-Dataset.json")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.to_excel("test.xlsx")

# %%
# Series => 1D
cars = pd.Series(["BMW", "Tesla", "Kia"])
print(cars)
# Out:
# 0      BMW
# 1    Tesla
# 2      Kia
# dtype: object

# %%
cars_series = data_with_missing["cars"]
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', None, 'Ford']
