# %% [markdown]
# <a href="https://colab.research.google.com/github/fkhaaan/ai_foundation/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Menu Detector!")
# Out:
# Menu Detector!

# %%
#=================
# Import Libraries
#=================
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = '/content/drive/MyDrive/food101_dataset'
print("Dataset_path:", DATASET_PATH)

CUSTOM_CLASSES = {
    "baklava": "baklava",
    "cheesecake": "dessert", # label grouping | class consolidation
    "pilaf": "pilaf",
    "pizza": "pizza",
    "chocolate_cake": "dessert" # label grouping | class consolidation
}

CLASSES = ['baklava', 'dessert', 'pilaf', 'pizza']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)

print(CLASS_TO_IDX)
# Out:
# Dataset_path: /content/drive/MyDrive/food101_dataset
# {'baklava': 0, 'cheesecake': 1, 'pilaf': 2, 'pizza': 3, 'chocolate_cake': 4}
